# %% [markdown]
# # Startup for a new session
#
# This notebook contains all of the necessary startup mechanisms to run up a session.

# %%
# %%bash
# # reconfigure pip to prevent config problems
# pip config unset global.extra-index-url
# # install keyring then reset the extra repository
# pip install keyring keyrings.google-artifactregistry-auth
# pip config set global.extra-index-url https://asia-southeast1-python.pkg.dev/kindling-2306/python/simple/
#
# pip install "cedar>=1.0,<1.1" --user

# %%
# !cat /home/shared/.admin/service-account.json
